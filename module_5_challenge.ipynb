# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
sales_2020_df = pd.read_csv("Resources/athletic_sales_2020.csv")
sales_2021_df = pd.read_csv("Resources/athletic_sales_2021.csv")

# %%
# Display the 2020 sales DataFrame
sales_2020_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
sales_2021_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
sales_2020_df["total_sales"].dtype
# Out:
# dtype('int64')

# %%
# Check the 2021 sales data types.
sales_2021_df["total_sales"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
combined_sales_df = pd.concat([sales_2020_df, sales_2021_df], axis = "rows", join = "inner")

combined_sales_reset_df = combined_sales_df.reset_index()

combined_sales_reset_df
# Out:
#       index     retailer  retailer_id invoice_date     region         state  \
# 0         0  Foot Locker      1185732       1/1/20  Northeast      New York
# 1         1  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2         2  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3         3  Foot Locker      1185732       1/1/20  Northeast      New York
# 4         4  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...     ...          ...          ...          ...        ...           ...
# 9638   8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9639   8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9640   8343       Amazon      1185732     12/31/21  Northeast         Maine
# 9641   8344       Amazon      1185732     12/31/21  Northeast         Maine
# 9642   8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
# ...

# %%
# Check if any values are null.
null_df = combined_sales_reset_df.isnull().sum()

null_df
# Out:
# index               0
# retailer            0
# retailer_id         0
# invoice_date        0
# region              0
# state               0
# city                0
# product             0
# price_per_unit      0
# units_sold          0
# total_sales         0
# operating_profit    0
# sales_method        0
# dtype: int64

# %%
# Check the data type of each column
combined_sales_reset_df.dtypes
# Out:
# index                 int64
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
combined_sales_reset_df["invoice_date"] = pd.to_datetime(combined_sales_reset_df["invoice_date"], errors='coerce' )
# Out:
# /var/folders/xw/v1jvfgnx0qd3b1ytj3y03tk00000gn/T/ipykernel_23372/2638528157.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   combined_sales_reset_df["invoice_date"] = pd.to_datetime(combined_sales_reset_df["invoice_date"], errors='coerce' )

# %%
# Confirm that the "invoice_date" data type has been changed.
combined_sales_reset_df.dtypes
# Out:
# index                        int64
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".
grouped_sales_df = combined_sales_reset_df.groupby(["region", "state", "city"])["units_sold"].sum().reset_index(name="Total_Products_Sold")

grouped_sales_sorted_df = grouped_sales_df.sort_values(by="Total_Products_Sold" , ascending=False)

# Show the top 5 results.
grouped_sales_sorted_df.head()
# Out:
#        region       state           city  Total_Products_Sold
# 21  Northeast    New York       New York               111954
# 33      South       Texas        Houston                90322
# 44       West  California  San Francisco                85478
# 43       West  California    Los Angeles                76384
# 34  Southeast     Florida          Miami                73135

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
pivot_grouped_sales_df = combined_sales_reset_df.pivot_table(
                                                values = "units_sold",
                                                index = ["region", "state", "city"],
                                                aggfunc = "sum").rename(columns = {"units_sold": "Total_Products_Sold"})

# Rename the "units_sold" column to "Total_Products_Sold"
# See above.

# Show the top 5 results.
pivot_grouped_sales_sorted_df = pivot_grouped_sales_df.sort_values(by = "Total_Products_Sold", ascending=False)

pivot_grouped_sales_sorted_df.head()
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"
grouped_sales_region_df = combined_sales_reset_df.groupby(["region", "state", "city"])["total_sales"].sum().reset_index()

grouped_sales_region_df = grouped_sales_region_df.rename(columns={"total_sales": "Total_Sales"})

grouped_sales_region_sorted_df = grouped_sales_region_df.sort_values(by="Total_Sales", ascending=False)
# Show the top 5 results.
grouped_sales_region_sorted_df.head()
# Out:
#        region           state           city  Total_Sales
# 21  Northeast        New York       New York     39801235
# 44       West      California  San Francisco     33973228
# 34  Southeast         Florida          Miami     31600863
# 39  Southeast  South Carolina     Charleston     29285637
# 35  Southeast         Florida        Orlando     27682851

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
pivot_grouped_region_df = combined_sales_reset_df.pivot_table(
                                                    values = "total_sales",
                                                    index = ["region", "state", "city"],
                                                    aggfunc = "sum").rename(columns = {"total_sales": "Total_Sales"})

# Optional: Rename the "total_sales" column to "Total Sales"
# See above.

# Show the top 5 results.
pivot_grouped_region_sorted_df = pivot_grouped_region_df.sort_values(by = "Total_Sales", ascending=False)

pivot_grouped_region_sorted_df.head()
# Chart has correct info, but does not look the same as the others. Consult TA before submitting.
# Out:
#                                         Total_Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"
grouped_retail_df = combined_sales_reset_df.groupby(["retailer", "region", "state", "city"])["total_sales"].sum().reset_index()

grouped_retail_df = grouped_retail_df.rename(columns={"total_sales": "Total_Sales"})

grouped_retail_sorted_df = grouped_retail_df.sort_values(by="Total_Sales", ascending=False)
# Show the top 5 results.
grouped_retail_sorted_df.head()
# Out:
#         retailer     region           state           city  Total_Sales
# 103    West Gear       West      California  San Francisco     32794405
# 50        Kohl's       West      California    Los Angeles     25127160
# 22   Foot Locker  Northeast        New York       New York     25008568
# 109    West Gear       West      Washington        Seattle     24862675
# 33   Foot Locker  Southeast  South Carolina     Charleston     24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
pivot_grouped_retail_df = combined_sales_reset_df.pivot_table(
                                                    values = "total_sales",
                                                    index = ["retailer", "region", "state", "city"],
                                                    aggfunc = "sum").rename(columns = {"total_sales": "Total_Sales"})

# Optional: Rename the "total_sales" column to "Total Sales"
# See above.

# Show the top 5 results.
pivot_grouped_retail_sorted_df = pivot_grouped_retail_df.sort_values(by = "Total_Sales", ascending=False)

pivot_grouped_retail_sorted_df.head()
# Out:
#                                                     Total_Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
womens_athletic_df = combined_sales_reset_df[combined_sales_reset_df["product"].str.contains("Women's Athletic Footwear")]
#df.loc[(df["column_name"] =="<value>")]
womens_athletic_df
# Out:
#       index     retailer  retailer_id invoice_date     region         state  \
# 21       21  Foot Locker      1185732   2020-01-04  Northeast      New York
# 22       22  Foot Locker      1185732   2020-01-04  Northeast      New York
# 23       23  Foot Locker      1185732   2020-01-04  Northeast      New York
# 26       26    West Gear      1128299   2020-01-05  Northeast  Pennsylvania
# 27       27    West Gear      1128299   2020-01-05  Northeast  Pennsylvania
# ...     ...          ...          ...          ...        ...           ...
# 9633   8336  Foot Locker      1185732   2021-12-30  Northeast  Pennsylvania
# 9634   8337  Foot Locker      1185732   2021-12-30  Northeast  Pennsylvania
# 9635   8338       Amazon      1185732   2021-12-30  Northeast         Maine
# 9636   8339       Amazon      1185732   2021-12-30  Northeast         Maine
# 9637   8340  Foot Locker      1185732   2021-12-30  Northeast  Pennsylvania
#
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
womens_athletic_grouped_df = womens_athletic_df.groupby(["retailer", "region", "state", "city"])["units_sold"].sum().reset_index()

womens_athletic_grouped_df = womens_athletic_grouped_df.rename(columns={"units_sold": "Womens_Footwear_Units_Sold"})

womens_athletic_grouped_sorted_df = womens_athletic_grouped_df.sort_values(by="Womens_Footwear_Units_Sold", ascending=False)

# Show the top 5 results.
womens_athletic_grouped_sorted_df.head()
# Out:
#           retailer     region           state           city  \
# 101      West Gear       West      California  San Francisco
# 22     Foot Locker  Northeast        New York       New York
# 49          Kohl's       West      California    Los Angeles
# 33     Foot Locker  Southeast  South Carolina     Charleston
# 68   Sports Direct      South           Texas         Dallas
#
#      Womens_Footwear_Units_Sold
# 101                       12107
# 22                        10996
# 49                        10826
# 33                         8814
# 68                         8790

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
pivot_womens_grouped_df = womens_athletic_df.pivot_table(
                                                    values = "units_sold",
                                                    index = ["retailer", "region", "state", "city"],
                                                    aggfunc = "sum").rename(columns = {"units_sold": "Womens_Footwear_Units_Sold"})

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
# See above.
# Show the top 5 results.
pivot_womens_grouped_sorted_df = pivot_womens_grouped_df.sort_values(by = "Womens_Footwear_Units_Sold", ascending=False)

pivot_womens_grouped_sorted_df.head()
# Out:
#                                                       Womens_Footwear_Units_Sold
# retailer      region    state          city
# West Gear     West      California     San Francisco                       12107
# Foot Locker   Northeast New York       New York                            10996
# Kohl's        West      California     Los Angeles                         10826
# Foot Locker   Southeast South Carolina Charleston                           8814
# Sports Direct South     Texas          Dallas                               8790

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
pivot_womens_grouped_day_df = womens_athletic_df.pivot_table(
                                                    values = "total_sales",
                                                    index = ["invoice_date"],
                                                    aggfunc = "sum").rename(columns = {"total_sales": "Total_Sales"})

# Optional: Rename the "total_sales" column to "Total Sales"
# See above.

# Show the table.
pivot_womens_grouped_day_df
# Out:
#               Total_Sales
# invoice_date
# 2020-01-04         402743
# 2020-01-05         141801
# 2020-01-11         129556
# 2020-01-17         173013
# 2020-01-22         388250
# ...                   ...
# 2021-12-22         200406
# 2021-12-23         808022
# 2021-12-24         190885
# 2021-12-25         315175
# 2021-12-30         167903
#
# [355 rows x 1 columns]

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
womens_daily_sales_df = pivot_womens_grouped_day_df.resample("D").sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
womens_daily_sales_sorted_df = womens_daily_sales_df.sort_values(by="Total_Sales", ascending=False)
# Notes on Challenge Rubric state descending order, notes on notebook state ascending order.
womens_daily_sales_sorted_df.head(10)
# head was changed to reflect example on Module 5 Challenge instructions.
# Out:
#               Total_Sales
# invoice_date
# 2021-07-16        1521825
# 2021-12-16        1473497
# 2021-06-17        1376988
# 2021-08-17        1086294
# 2021-07-23        1021806
# 2021-11-17        1021145
# 2021-12-09         915011
# 2021-06-24         884238
# 2021-07-09         869054
# 2021-08-10         839120

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.
womens_weekly_sales_df = pivot_womens_grouped_day_df.resample("W-SUN").sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
womens_weekly_sales_sorted_df = womens_weekly_sales_df.sort_values(by="Total_Sales", ascending=False)

womens_weekly_sales_sorted_df.head(10)
# Out:
#               Total_Sales
# invoice_date
# 2021-12-19        3098970
# 2021-12-12        2922161
# 2021-07-11        2835078
# 2021-07-18        2801449
# 2021-11-14        2531721
# 2021-08-22        2491259
# 2021-08-15        2463941
# 2021-11-21        2449537
# 2021-05-16        2422132
# 2021-06-13        2358602

# %%
#Following code was used to troubleshoot issues I was having with the last problem with weekly binning. It is not a part of the assignment but left in
#as part of citing thought processes and support I received from BCS


#specific_dates = ['2021-12-19', '2021-12-12', '2021-07-11', '2021-07-18', '2021-11-14', '2021-08-22', '2021-08-15', '2021-11-21', '2021-05-16', '2021-06-13']
#specific_dates_dt = pd.to_datetime(specific_dates)  # Ensure the dates are in datetime format

# Check presence in the DataFrame index
#dates_presence = specific_dates_dt.isin(womens_daily_sales_df.index)

# Print results
#for date, is_present in zip(specific_dates_dt, dates_presence):
#   print(f"Date {date.date()}: {'Present' if is_present else 'Missing'}")
# Out:
# Date 2021-12-19: Present
# Date 2021-12-12: Present
# Date 2021-07-11: Present
# Date 2021-07-18: Present
# Date 2021-11-14: Present
# Date 2021-08-22: Present
# Date 2021-08-15: Present
# Date 2021-11-21: Present
# Date 2021-05-16: Present
# Date 2021-06-13: Present
